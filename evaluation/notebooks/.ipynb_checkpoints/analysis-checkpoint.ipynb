# %% [markdown]
# # Ramp-Metering Strategy Analysis
#
# A self-contained KPI analysis comparing **all 12 control strategies** across six headline metrics, with a configurable **focus-strategy deep dive**.
#
# **Sections**
# 1. Setup & Configuration
# 2. Helpers & Data Loading
# 3. KPI Dashboard — All Strategies
# 4. Composite Score & Radar
# 5. Pairwise Improvement Matrix
# 6. Demand-Conditioned KPI Heatmaps
# 7. Focus Strategy Deep Dive
# 8. Robustness & Trade-offs

# %% [markdown]
# ## 1. Setup & Configuration

# %%
from __future__ import annotations

import re
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import Markdown, display

BENCHMARKS_DIR = (Path(".") / "../benchmarks").resolve()
PLOTS_DIR = Path("plots") / "analysis"

sns.set_theme(
    context="paper",
    style="whitegrid",
    palette="deep",
    font_scale=1.15,
    rc={
        "figure.figsize": (12, 7),
        "grid.linestyle": "--",
        "grid.color": "0.85",
        "axes.spines.top": False,
        "axes.spines.right": False,
    },
)

# %% [markdown]
# ### Configuration
#
# `FOCUS_STRATEGY` is the single knob driving Section 7's deep dive — change it and re-run the focus section to compare any strategy against the others.
#
# `HIGHER_IS_BETTER` lists the metrics where larger values are better (only mainline merge speed). Every ranking and improvement calculation respects this direction.

# %%
# (display name, csv filename, color)
STRATEGY_CATALOG: list[tuple[str, str, str]] = [
    # ("DQN Hybrid (Partial Obs.)",        "results_DQNAgentHybridPartial.csv",    "#1f77b4"),
    # ("DQN Hybrid (Full Obs.)",           "results_DQNAgentHybridFull.csv",       "#ff7f0e"),
    # ("DQN Macro + Lane Obs.",            "results_DQNAgentMacroLane.csv",        "#2ca02c"),
    # ("DQN Macro (No Lane Obs.)",         "results_DQNAgentMacroNoLaneNew.csv",   "#d62728"),
    ("RM Only",                          "results_DQNAgentMacroLane.csv",   "#d62728"),
    # ("DQN Macro with PER (No Lane Obs.)","results_DQNAgentHybridPartialPer.csv", "#9467bd"),
    # ("DQN Hybrid (Full Obs.) - New",     "results_DQNAgentHybridFull_NEW.csv",   "#e377c2"),
    ("ALINEA",                           "results_AlineaDsBaseline.csv",         "#7f7f7f"),
    ("PI-ALINEA",                        "results_PiAlineaDsBaseline.csv",       "#bcbd22"),
    ("Fixed-Control",                    "results_FixedCycleBaseline.csv",       "#17becf"),
    ("No Control",                       "results_AlwaysGreenBaseline.csv",      "#aec7e8"),
    ("RM+LCC",              "results_DQNAgent_ramp_metering_lane_control_hybrid.csv",      "#a7c7e8"),
]

ALL_STRATEGIES   = [n for n, _, _ in STRATEGY_CATALOG]
STRATEGY_FILES   = {n: str(BENCHMARKS_DIR / f) for n, f, _ in STRATEGY_CATALOG}
STRATEGY_COLORS  = {n: c for n, _, c in STRATEGY_CATALOG}

METRICS = {
    "total_travel_time":                 "Total Time Spent (s)",
    "avg_time_loss":                     "Average Delay (s/veh)",
    "avg_ramp_queue_veh":                "Average Queue Length (veh)",
    "total_spillback_time_sec":          "Total Spillback (s)",
    "avg_mainline_speed_mergeArea_km/h": "Average Merge Speed (km/h)",
    "total_co2_mg":                      "Total CO2 Emissions (mg)",
}
HIGHER_IS_BETTER = {"avg_mainline_speed_mergeArea_km/h"}

MAINLINE_LEVELS = ["Low Mainline", "Medium Mainline", "High Mainline"]
RAMP_LEVELS     = ["Low On-Ramp",  "Medium On-Ramp",  "High On-Ramp"]

# === Change this to deep-dive any other strategy in Section 7 ===
FOCUS_STRATEGY = "RM+LCC"
FOCUS_COLOR    = "#111111"   # accent for focus strategy in head-to-head plots

# %% [markdown]
# ## 2. Helpers & Data Loading
#
# Load all 12 benchmark CSVs, tag rows with their strategy name, and bin every episode into one of 9 demand cells (3 mainline × 3 on-ramp).

# %%
def slugify(text: str) -> str:
    text = text.lower().strip()
    text = re.sub(r"[\s/]+", "_", text)
    return re.sub(r"[^\w-]", "", text)


def metric_sort_ascending(metric_key: str) -> bool:
    return metric_key not in HIGHER_IS_BETTER


def pct_improvement(focus_val: float, other_val: float, metric_key: str) -> float:
    """Positive = focus is better than other."""
    if other_val == 0:
        return np.nan
    if metric_key in HIGHER_IS_BETTER:
        return ((focus_val - other_val) / other_val) * 100
    return ((other_val - focus_val) / other_val) * 100


def normalize_metric(series: pd.Series, metric_key: str) -> pd.Series:
    """Min-max scale to [0, 1] where 1 = best, regardless of metric direction."""
    lo, hi = series.min(), series.max()
    if hi == lo:
        return pd.Series(np.ones_like(series, dtype=float), index=series.index)
    scaled = (series - lo) / (hi - lo)
    return scaled if metric_key in HIGHER_IS_BETTER else 1 - scaled


def save_fig(fig: plt.Figure, section: str, title: str, dpi: int = 200) -> Path:
    out = PLOTS_DIR / section
    out.mkdir(parents=True, exist_ok=True)
    path = out / f"{slugify(title)}.png"
    fig.savefig(path, dpi=dpi, bbox_inches="tight")
    return path


def load_benchmarks() -> pd.DataFrame:
    frames = []
    for strategy, filepath in STRATEGY_FILES.items():
        p = Path(filepath)
        if not p.is_file():
            print(f"Warning: missing '{p.name}' — skipping {strategy}.")
            continue
        df = pd.read_csv(p)
        df.columns = df.columns.str.strip()
        df["strategy"] = strategy
        frames.append(df)
    if not frames:
        raise RuntimeError("No benchmark CSVs were loaded.")
    return pd.concat(frames, ignore_index=True)


def categorize_demand(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df["mainline_demand"] = pd.cut(
        df["main_flow_vph"], bins=[0, 4750, 5750, float("inf")],
        labels=MAINLINE_LEVELS, right=False,
    )
    df["on_ramp_demand"] = pd.cut(
        df["on_ramp_flow_vph"], bins=[0, 1600, 1800, float("inf")],
        labels=RAMP_LEVELS, right=False,
    )
    df["demand_cell"] = df["mainline_demand"].astype(str) + " / " + df["on_ramp_demand"].astype(str)
    return df

# %%
df = categorize_demand(load_benchmarks())
present_strategies = [s for s in ALL_STRATEGIES if s in df["strategy"].unique()]

print(f"Loaded {len(df):,} rows across {len(present_strategies)} strategies.\n")
roster = df.groupby("strategy", sort=False).size().rename("episodes").to_frame()
roster = roster.reindex(present_strategies)
display(roster.style.background_gradient(cmap="Blues"))

assert FOCUS_STRATEGY in present_strategies, (
    f"FOCUS_STRATEGY '{FOCUS_STRATEGY}' was not loaded — check STRATEGY_CATALOG."
)
# Out:
# Loaded 300 rows across 6 strategies.
# <style type="text/css">
# #T_0f0c5_row0_col0, #T_0f0c5_row1_col0, #T_0f0c5_row2_col0, #T_0f0c5_row3_col0, #T_0f0c5_row4_col0, #T_0f0c5_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_0f0c5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >episodes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >strategy</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f0c5_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_0f0c5_row0_col0" class="data row0 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_0f0c5_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_0f0c5_row1_col0" class="data row1 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_0f0c5_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_0f0c5_row2_col0" class="data row2 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_0f0c5_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_0f0c5_row3_col0" class="data row3 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_0f0c5_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_0f0c5_row4_col0" class="data row4 col0" >50</td>
#     </tr>
#     <tr>
#       <th id="T_0f0c5_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_0f0c5_row5_col0" class="data row5 col0" >50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. KPI Dashboard — All Strategies
#
# A three-panel view of every strategy on every headline KPI:
# - **Heatmap table** of mean KPI values, colour-graded per column (green = better)
# - **Bar chart** per KPI, sorted best → worst, with the focus strategy outlined
# - **Violin plot** per KPI, showing the per-episode distribution shape across all 50 episodes

# %%
strategy_means = (
    df.groupby("strategy", sort=False)[list(METRICS)].mean().reindex(present_strategies)
)
strategy_means_display = strategy_means.rename(columns=METRICS)

styled = strategy_means_display.style.format("{:,.2f}")
for metric_key, metric_name in METRICS.items():
    cmap = "RdYlGn" if metric_key in HIGHER_IS_BETTER else "RdYlGn_r"
    styled = styled.background_gradient(cmap=cmap, subset=[metric_name], axis=0)

display(Markdown("**Per-strategy mean of each KPI** (column-wise gradient — green is better)"))
display(styled)
# Out:
# **Per-strategy mean of each KPI** (column-wise gradient — green is better)
# <style type="text/css">
# #T_76d8f_row0_col0 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_76d8f_row0_col1 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_76d8f_row0_col2 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_76d8f_row0_col3 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_76d8f_row0_col4 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_76d8f_row0_col5 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_76d8f_row1_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_76d8f_row1_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_76d8f_row1_col2 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_76d8f_row1_col3 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_76d8f_row1_col4 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_76d8f_row1_col5, #T_76d8f_row5_col3 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_76d8f_row2_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_76d8f_row2_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_76d8f_row2_col2 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_76d8f_row2_col3, #T_76d8f_row3_col2, #T_76d8f_row4_col0, #T_76d8f_row4_col1, #T_76d8f_row4_col4, #T_76d8f_row4_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_76d8f_row2_col4 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_76d8f_row2_col5 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_76d8f_row3_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_76d8f_row3_col1 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_76d8f_row3_col3, #T_76d8f_row3_col4, #T_76d8f_row3_col5, #T_76d8f_row4_col2, #T_76d8f_row4_col3, #T_76d8f_row5_col0, #T_76d8f_row5_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_76d8f_row5_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_76d8f_row5_col4 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_76d8f_row5_col5 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_76d8f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Time Spent (s)</th>
#       <th class="col_heading level0 col1" >Average Delay (s/veh)</th>
#       <th class="col_heading level0 col2" >Average Queue Length (veh)</th>
#       <th class="col_heading level0 col3" >Total Spillback (s)</th>
#       <th class="col_heading level0 col4" >Average Merge Speed (km/h)</th>
#       <th class="col_heading level0 col5" >Total CO2 Emissions (mg)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >strategy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76d8f_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_76d8f_row0_col0" class="data row0 col0" >382,884.04</td>
#       <td id="T_76d8f_row0_col1" class="data row0 col1" >22.00</td>
#       <td id="T_76d8f_row0_col2" class="data row0 col2" >14.47</td>
#       <td id="T_76d8f_row0_col3" class="data row0 col3" >94.40</td>
#       <td id="T_76d8f_row0_col4" class="data row0 col4" >13.52</td>
#       <td id="T_76d8f_row0_col5" class="data row0 col5" >1,798,629,842.56</td>
#     </tr>
#     <tr>
#       <th id="T_76d8f_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_76d8f_row1_col0" class="data row1 col0" >417,836.80</td>
#       <td id="T_76d8f_row1_col1" class="data row1 col1" >27.53</td>
#       <td id="T_76d8f_row1_col2" class="data row1 col2" >14.18</td>
#       <td id="T_76d8f_row1_col3" class="data row1 col3" >381.30</td>
#       <td id="T_76d8f_row1_col4" class="data row1 col4" >13.41</td>
#       <td id="T_76d8f_row1_col5" class="data row1 col5" >1,646,573,304.66</td>
#     </tr>
#     <tr>
#       <th id="T_76d8f_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_76d8f_row2_col0" class="data row2 col0" >426,418.10</td>
#       <td id="T_76d8f_row2_col1" class="data row2 col1" >29.10</td>
#       <td id="T_76d8f_row2_col2" class="data row2 col2" >14.28</td>
#       <td id="T_76d8f_row2_col3" class="data row2 col3" >625.28</td>
#       <td id="T_76d8f_row2_col4" class="data row2 col4" >13.48</td>
#       <td id="T_76d8f_row2_col5" class="data row2 col5" >1,656,096,458.08</td>
#     </tr>
#     <tr>
#       <th id="T_76d8f_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_76d8f_row3_col0" class="data row3 col0" >386,182.16</td>
#       <td id="T_76d8f_row3_col1" class="data row3 col1" >23.52</td>
#       <td id="T_76d8f_row3_col2" class="data row3 col2" >15.57</td>
#       <td id="T_76d8f_row3_col3" class="data row3 col3" >1.58</td>
#       <td id="T_76d8f_row3_col4" class="data row3 col4" >14.18</td>
#       <td id="T_76d8f_row3_col5" class="data row3 col5" >1,576,992,817.73</td>
#     </tr>
#     <tr>
#       <th id="T_76d8f_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_76d8f_row4_col0" class="data row4 col0" >576,047.16</td>
#       <td id="T_76d8f_row4_col1" class="data row4 col1" >57.21</td>
#       <td id="T_76d8f_row4_col2" class="data row4 col2" >10.06</td>
#       <td id="T_76d8f_row4_col3" class="data row4 col3" >1.40</td>
#       <td id="T_76d8f_row4_col4" class="data row4 col4" >12.62</td>
#       <td id="T_76d8f_row4_col5" class="data row4 col5" >1,822,323,144.65</td>
#     </tr>
#     <tr>
#       <th id="T_76d8f_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_76d8f_row5_col0" class="data row5 col0" >372,863.74</td>
#       <td id="T_76d8f_row5_col1" class="data row5 col1" >19.72</td>
#       <td id="T_76d8f_row5_col2" class="data row5 col2" >14.33</td>
#       <td id="T_76d8f_row5_col3" class="data row5 col3" >179.20</td>
#       <td id="T_76d8f_row5_col4" class="data row5 col4" >13.78</td>
#       <td id="T_76d8f_row5_col5" class="data row5 col5" >1,580,634,875.20</td>
#     </tr>
#   </tbody>
# </table>

# %%
for metric_key, metric_name in METRICS.items():
    asc = metric_sort_ascending(metric_key)
    series = strategy_means[metric_key].sort_values(ascending=asc)
    colors = [STRATEGY_COLORS[s] for s in series.index]
    edges  = ["black" if s == FOCUS_STRATEGY else "none" for s in series.index]
    widths = [2.5     if s == FOCUS_STRATEGY else 0      for s in series.index]

    fig, ax = plt.subplots(figsize=(10, 6))
    bars = ax.barh(series.index, series.values, color=colors,
                   edgecolor=edges, linewidth=widths)
    title = f"Mean {metric_name} — sorted best to worst"
    ax.set_title(title, fontsize=14)
    ax.set_xlabel(metric_name)
    ax.invert_yaxis()
    for bar, val in zip(bars, series.values):
        ax.text(val, bar.get_y() + bar.get_height() / 2,
                f"  {val:,.1f}", va="center", fontsize=9)
    save_fig(fig, "kpi_dashboard", title)
    plt.tight_layout()
    plt.show()
    plt.close(fig)

# %%
df_ordered = df.copy()
df_ordered["strategy"] = pd.Categorical(df_ordered["strategy"],
                                        categories=present_strategies, ordered=True)
palette = [STRATEGY_COLORS[s] for s in present_strategies]

for metric_key, metric_name in METRICS.items():
    fig, ax = plt.subplots(figsize=(13, 6))
    sns.violinplot(data=df_ordered, x="strategy", y=metric_key,
                   palette=palette, inner="quartile", cut=0, ax=ax)
    title = f"{metric_name} — per-episode distribution"
    ax.set_title(title, fontsize=14)
    ax.set_xlabel("")
    ax.set_ylabel(metric_name)
    ax.tick_params(axis="x", rotation=35)
    for label in ax.get_xticklabels():
        if label.get_text() == FOCUS_STRATEGY:
            label.set_fontweight("bold")
    save_fig(fig, "kpi_dashboard", title)
    plt.tight_layout()
    plt.show()
    plt.close(fig)

# %% [markdown]
# ## 4. Composite Score & Radar
#
# Min-max normalize each KPI so that **1.0 = best** regardless of metric direction, then average the six normalized scores into a single composite. The radar chart compares the focus strategy against the top-3 composite performers and the bottom one — a quick visual signature.

# %%
normalized = pd.DataFrame(
    {k: normalize_metric(strategy_means[k], k) for k in METRICS},
    index=strategy_means.index,
)
composite = normalized.mean(axis=1).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 6))
colors = [STRATEGY_COLORS[s] for s in composite.index]
edges  = ["black" if s == FOCUS_STRATEGY else "none" for s in composite.index]
widths = [2.5     if s == FOCUS_STRATEGY else 0      for s in composite.index]
bars = ax.barh(composite.index, composite.values, color=colors,
               edgecolor=edges, linewidth=widths)
title = "Composite KPI score (mean of normalized KPIs, higher is better)"
ax.set_title(title, fontsize=14)
ax.set_xlabel("Composite score  (1.0 = best on every KPI)")
ax.set_xlim(0, 1.05)
ax.invert_yaxis()
for bar, val in zip(bars, composite.values):
    ax.text(val + 0.005, bar.get_y() + bar.get_height() / 2,
            f"{val:.3f}", va="center", fontsize=9)
save_fig(fig, "composite", title)
plt.tight_layout()
plt.show()
plt.close(fig)

display(Markdown(
    f"**Focus strategy ‹{FOCUS_STRATEGY}› composite rank: "
    f"{list(composite.index).index(FOCUS_STRATEGY) + 1} / {len(composite)}**"
))
# Out:
# **Focus strategy ‹RM+LCC› composite rank: 2 / 6**

# %%
top3 = [s for s in composite.head(3).index]
worst = composite.tail(1).index[0]
radar_strategies = list(dict.fromkeys([FOCUS_STRATEGY, *top3, worst]))   # unique, ordered

labels  = [METRICS[k] for k in METRICS]
angles  = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(polar=True))
for strat in radar_strategies:
    values = normalized.loc[strat].tolist()
    values += values[:1]
    is_focus = strat == FOCUS_STRATEGY
    ax.plot(angles, values, color=STRATEGY_COLORS[strat],
            linewidth=3 if is_focus else 1.8,
            label=strat + (" ★" if is_focus else ""))
    ax.fill(angles, values, color=STRATEGY_COLORS[strat],
            alpha=0.20 if is_focus else 0.08)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=10)
ax.set_yticks([0.25, 0.5, 0.75, 1.0])
ax.set_yticklabels(["0.25", "0.5", "0.75", "1.0"], fontsize=8)
ax.set_ylim(0, 1)
title = f"Radar — Focus vs. top-3 vs. worst (normalized KPIs)"
ax.set_title(title, y=1.10, fontsize=14)
ax.legend(loc="upper right", bbox_to_anchor=(1.35, 1.10), fontsize=10)
save_fig(fig, "composite", title)
plt.tight_layout()
plt.show()
plt.close(fig)

# %% [markdown]
# ## 5. Pairwise Improvement Matrix
#
# For each KPI, every cell shows the percentage improvement of the **row** strategy over the **column** strategy. Green = row wins, red = row loses. Values are clipped at ±100 % for readability.

# %%
for metric_key, metric_name in METRICS.items():
    matrix = pd.DataFrame(index=present_strategies, columns=present_strategies, dtype=float)
    for r in present_strategies:
        for c in present_strategies:
            matrix.loc[r, c] = 0.0 if r == c else pct_improvement(
                strategy_means.loc[r, metric_key],
                strategy_means.loc[c, metric_key],
                metric_key,
            )
    display(Markdown(f"### Improvement matrix — {metric_name}"))
    display(
        matrix.style
        .background_gradient(cmap="RdYlGn", axis=None, vmin=-100, vmax=100)
        .format("{:+.1f}%")
        .set_caption("Row strategy vs. column strategy")
    )
# Out:
# ### Improvement matrix — Total Time Spent (s)
# <style type="text/css">
# #T_382f5_row0_col0, #T_382f5_row1_col1, #T_382f5_row2_col2, #T_382f5_row3_col3, #T_382f5_row4_col4, #T_382f5_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_382f5_row0_col1 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_382f5_row0_col2, #T_382f5_row5_col1 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_382f5_row0_col3 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_382f5_row0_col4, #T_382f5_row3_col4 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_382f5_row0_col5 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_382f5_row1_col0 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_382f5_row1_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_382f5_row1_col3 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_382f5_row1_col4 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_382f5_row1_col5 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_382f5_row2_col0 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_382f5_row2_col1 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_382f5_row2_col3 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_382f5_row2_col4 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_382f5_row2_col5 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_382f5_row3_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_382f5_row3_col1 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_382f5_row3_col2 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_382f5_row3_col5 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_382f5_row4_col0 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_382f5_row4_col1 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_382f5_row4_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_382f5_row4_col3 {
#   background-color: #f99153;
#   color: #000000;
# }
# #T_382f5_row4_col5 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_382f5_row5_col0 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_382f5_row5_col2 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_382f5_row5_col3 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_382f5_row5_col4 {
#   background-color: #b1de71;
#   color: #000000;
# }
# </style>
# <table id="T_382f5_">
#   <caption>Row strategy vs. column strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >RM Only</th>
#       <th class="col_heading level0 col1" >ALINEA</th>
#       <th class="col_heading level0 col2" >PI-ALINEA</th>
#       <th class="col_heading level0 col3" >Fixed-Control</th>
#       <th class="col_heading level0 col4" >No Control</th>
#       <th class="col_heading level0 col5" >RM+LCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_382f5_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_382f5_row0_col0" class="data row0 col0" >+0.0%</td>
#       <td id="T_382f5_row0_col1" class="data row0 col1" >+8.4%</td>
#       <td id="T_382f5_row0_col2" class="data row0 col2" >+10.2%</td>
#       <td id="T_382f5_row0_col3" class="data row0 col3" >+0.9%</td>
#       <td id="T_382f5_row0_col4" class="data row0 col4" >+33.5%</td>
#       <td id="T_382f5_row0_col5" class="data row0 col5" >-2.7%</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_382f5_row1_col0" class="data row1 col0" >-9.1%</td>
#       <td id="T_382f5_row1_col1" class="data row1 col1" >+0.0%</td>
#       <td id="T_382f5_row1_col2" class="data row1 col2" >+2.0%</td>
#       <td id="T_382f5_row1_col3" class="data row1 col3" >-8.2%</td>
#       <td id="T_382f5_row1_col4" class="data row1 col4" >+27.5%</td>
#       <td id="T_382f5_row1_col5" class="data row1 col5" >-12.1%</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_382f5_row2_col0" class="data row2 col0" >-11.4%</td>
#       <td id="T_382f5_row2_col1" class="data row2 col1" >-2.1%</td>
#       <td id="T_382f5_row2_col2" class="data row2 col2" >+0.0%</td>
#       <td id="T_382f5_row2_col3" class="data row2 col3" >-10.4%</td>
#       <td id="T_382f5_row2_col4" class="data row2 col4" >+26.0%</td>
#       <td id="T_382f5_row2_col5" class="data row2 col5" >-14.4%</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_382f5_row3_col0" class="data row3 col0" >-0.9%</td>
#       <td id="T_382f5_row3_col1" class="data row3 col1" >+7.6%</td>
#       <td id="T_382f5_row3_col2" class="data row3 col2" >+9.4%</td>
#       <td id="T_382f5_row3_col3" class="data row3 col3" >+0.0%</td>
#       <td id="T_382f5_row3_col4" class="data row3 col4" >+33.0%</td>
#       <td id="T_382f5_row3_col5" class="data row3 col5" >-3.6%</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_382f5_row4_col0" class="data row4 col0" >-50.4%</td>
#       <td id="T_382f5_row4_col1" class="data row4 col1" >-37.9%</td>
#       <td id="T_382f5_row4_col2" class="data row4 col2" >-35.1%</td>
#       <td id="T_382f5_row4_col3" class="data row4 col3" >-49.2%</td>
#       <td id="T_382f5_row4_col4" class="data row4 col4" >+0.0%</td>
#       <td id="T_382f5_row4_col5" class="data row4 col5" >-54.5%</td>
#     </tr>
#     <tr>
#       <th id="T_382f5_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_382f5_row5_col0" class="data row5 col0" >+2.6%</td>
#       <td id="T_382f5_row5_col1" class="data row5 col1" >+10.8%</td>
#       <td id="T_382f5_row5_col2" class="data row5 col2" >+12.6%</td>
#       <td id="T_382f5_row5_col3" class="data row5 col3" >+3.4%</td>
#       <td id="T_382f5_row5_col4" class="data row5 col4" >+35.3%</td>
#       <td id="T_382f5_row5_col5" class="data row5 col5" >+0.0%</td>
#     </tr>
#   </tbody>
# </table>
# ### Improvement matrix — Average Delay (s/veh)
# <style type="text/css">
# #T_1848a_row0_col0, #T_1848a_row1_col1, #T_1848a_row2_col2, #T_1848a_row3_col3, #T_1848a_row4_col4, #T_1848a_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_1848a_row0_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_1848a_row0_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_1848a_row0_col3 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_1848a_row0_col4 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_1848a_row0_col5 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_1848a_row1_col0 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_1848a_row1_col2 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_1848a_row1_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_1848a_row1_col4 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_1848a_row1_col5 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_1848a_row2_col0 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_1848a_row2_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_1848a_row2_col3 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_1848a_row2_col4 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_1848a_row2_col5 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_1848a_row3_col0 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_1848a_row3_col1 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_1848a_row3_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_1848a_row3_col4 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_1848a_row3_col5 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_1848a_row4_col0, #T_1848a_row4_col1, #T_1848a_row4_col3, #T_1848a_row4_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1848a_row4_col2 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_1848a_row5_col0 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_1848a_row5_col1 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_1848a_row5_col2 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_1848a_row5_col3 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_1848a_row5_col4 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1848a_">
#   <caption>Row strategy vs. column strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >RM Only</th>
#       <th class="col_heading level0 col1" >ALINEA</th>
#       <th class="col_heading level0 col2" >PI-ALINEA</th>
#       <th class="col_heading level0 col3" >Fixed-Control</th>
#       <th class="col_heading level0 col4" >No Control</th>
#       <th class="col_heading level0 col5" >RM+LCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1848a_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_1848a_row0_col0" class="data row0 col0" >+0.0%</td>
#       <td id="T_1848a_row0_col1" class="data row0 col1" >+20.1%</td>
#       <td id="T_1848a_row0_col2" class="data row0 col2" >+24.4%</td>
#       <td id="T_1848a_row0_col3" class="data row0 col3" >+6.5%</td>
#       <td id="T_1848a_row0_col4" class="data row0 col4" >+61.5%</td>
#       <td id="T_1848a_row0_col5" class="data row0 col5" >-11.6%</td>
#     </tr>
#     <tr>
#       <th id="T_1848a_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_1848a_row1_col0" class="data row1 col0" >-25.1%</td>
#       <td id="T_1848a_row1_col1" class="data row1 col1" >+0.0%</td>
#       <td id="T_1848a_row1_col2" class="data row1 col2" >+5.4%</td>
#       <td id="T_1848a_row1_col3" class="data row1 col3" >-17.0%</td>
#       <td id="T_1848a_row1_col4" class="data row1 col4" >+51.9%</td>
#       <td id="T_1848a_row1_col5" class="data row1 col5" >-39.6%</td>
#     </tr>
#     <tr>
#       <th id="T_1848a_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_1848a_row2_col0" class="data row2 col0" >-32.3%</td>
#       <td id="T_1848a_row2_col1" class="data row2 col1" >-5.7%</td>
#       <td id="T_1848a_row2_col2" class="data row2 col2" >+0.0%</td>
#       <td id="T_1848a_row2_col3" class="data row2 col3" >-23.7%</td>
#       <td id="T_1848a_row2_col4" class="data row2 col4" >+49.1%</td>
#       <td id="T_1848a_row2_col5" class="data row2 col5" >-47.6%</td>
#     </tr>
#     <tr>
#       <th id="T_1848a_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_1848a_row3_col0" class="data row3 col0" >-6.9%</td>
#       <td id="T_1848a_row3_col1" class="data row3 col1" >+14.6%</td>
#       <td id="T_1848a_row3_col2" class="data row3 col2" >+19.2%</td>
#       <td id="T_1848a_row3_col3" class="data row3 col3" >+0.0%</td>
#       <td id="T_1848a_row3_col4" class="data row3 col4" >+58.9%</td>
#       <td id="T_1848a_row3_col5" class="data row3 col5" >-19.3%</td>
#     </tr>
#     <tr>
#       <th id="T_1848a_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_1848a_row4_col0" class="data row4 col0" >-160.0%</td>
#       <td id="T_1848a_row4_col1" class="data row4 col1" >-107.8%</td>
#       <td id="T_1848a_row4_col2" class="data row4 col2" >-96.6%</td>
#       <td id="T_1848a_row4_col3" class="data row4 col3" >-143.2%</td>
#       <td id="T_1848a_row4_col4" class="data row4 col4" >+0.0%</td>
#       <td id="T_1848a_row4_col5" class="data row4 col5" >-190.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1848a_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_1848a_row5_col0" class="data row5 col0" >+10.4%</td>
#       <td id="T_1848a_row5_col1" class="data row5 col1" >+28.4%</td>
#       <td id="T_1848a_row5_col2" class="data row5 col2" >+32.2%</td>
#       <td id="T_1848a_row5_col3" class="data row5 col3" >+16.2%</td>
#       <td id="T_1848a_row5_col4" class="data row5 col4" >+65.5%</td>
#       <td id="T_1848a_row5_col5" class="data row5 col5" >+0.0%</td>
#     </tr>
#   </tbody>
# </table>
# ### Improvement matrix — Average Queue Length (veh)
# <style type="text/css">
# #T_a0569_row0_col0, #T_a0569_row1_col1, #T_a0569_row1_col2, #T_a0569_row2_col2, #T_a0569_row2_col5, #T_a0569_row3_col3, #T_a0569_row4_col4, #T_a0569_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_a0569_row0_col1 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_a0569_row0_col2, #T_a0569_row0_col5, #T_a0569_row5_col1 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_a0569_row0_col3 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_a0569_row0_col4 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_a0569_row1_col0 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_a0569_row1_col3 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_a0569_row1_col4 {
#   background-color: #fcaa5f;
#   color: #000000;
# }
# #T_a0569_row1_col5, #T_a0569_row2_col0, #T_a0569_row5_col0 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_a0569_row2_col1, #T_a0569_row5_col2 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_a0569_row2_col3, #T_a0569_row5_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_a0569_row2_col4 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_a0569_row3_col0 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_a0569_row3_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_a0569_row3_col2, #T_a0569_row3_col5 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_a0569_row3_col4 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_a0569_row4_col0, #T_a0569_row4_col5 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_a0569_row4_col1, #T_a0569_row4_col2 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_a0569_row4_col3 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_a0569_row5_col4 {
#   background-color: #fca55d;
#   color: #000000;
# }
# </style>
# <table id="T_a0569_">
#   <caption>Row strategy vs. column strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >RM Only</th>
#       <th class="col_heading level0 col1" >ALINEA</th>
#       <th class="col_heading level0 col2" >PI-ALINEA</th>
#       <th class="col_heading level0 col3" >Fixed-Control</th>
#       <th class="col_heading level0 col4" >No Control</th>
#       <th class="col_heading level0 col5" >RM+LCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0569_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_a0569_row0_col0" class="data row0 col0" >+0.0%</td>
#       <td id="T_a0569_row0_col1" class="data row0 col1" >-2.1%</td>
#       <td id="T_a0569_row0_col2" class="data row0 col2" >-1.3%</td>
#       <td id="T_a0569_row0_col3" class="data row0 col3" >+7.1%</td>
#       <td id="T_a0569_row0_col4" class="data row0 col4" >-43.8%</td>
#       <td id="T_a0569_row0_col5" class="data row0 col5" >-1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a0569_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_a0569_row1_col0" class="data row1 col0" >+2.0%</td>
#       <td id="T_a0569_row1_col1" class="data row1 col1" >+0.0%</td>
#       <td id="T_a0569_row1_col2" class="data row1 col2" >+0.7%</td>
#       <td id="T_a0569_row1_col3" class="data row1 col3" >+9.0%</td>
#       <td id="T_a0569_row1_col4" class="data row1 col4" >-40.9%</td>
#       <td id="T_a0569_row1_col5" class="data row1 col5" >+1.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a0569_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_a0569_row2_col0" class="data row2 col0" >+1.3%</td>
#       <td id="T_a0569_row2_col1" class="data row2 col1" >-0.7%</td>
#       <td id="T_a0569_row2_col2" class="data row2 col2" >+0.0%</td>
#       <td id="T_a0569_row2_col3" class="data row2 col3" >+8.3%</td>
#       <td id="T_a0569_row2_col4" class="data row2 col4" >-41.9%</td>
#       <td id="T_a0569_row2_col5" class="data row2 col5" >+0.4%</td>
#     </tr>
#     <tr>
#       <th id="T_a0569_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_a0569_row3_col0" class="data row3 col0" >-7.6%</td>
#       <td id="T_a0569_row3_col1" class="data row3 col1" >-9.8%</td>
#       <td id="T_a0569_row3_col2" class="data row3 col2" >-9.1%</td>
#       <td id="T_a0569_row3_col3" class="data row3 col3" >+0.0%</td>
#       <td id="T_a0569_row3_col4" class="data row3 col4" >-54.8%</td>
#       <td id="T_a0569_row3_col5" class="data row3 col5" >-8.7%</td>
#     </tr>
#     <tr>
#       <th id="T_a0569_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_a0569_row4_col0" class="data row4 col0" >+30.5%</td>
#       <td id="T_a0569_row4_col1" class="data row4 col1" >+29.0%</td>
#       <td id="T_a0569_row4_col2" class="data row4 col2" >+29.5%</td>
#       <td id="T_a0569_row4_col3" class="data row4 col3" >+35.4%</td>
#       <td id="T_a0569_row4_col4" class="data row4 col4" >+0.0%</td>
#       <td id="T_a0569_row4_col5" class="data row4 col5" >+29.8%</td>
#     </tr>
#     <tr>
#       <th id="T_a0569_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_a0569_row5_col0" class="data row5 col0" >+1.0%</td>
#       <td id="T_a0569_row5_col1" class="data row5 col1" >-1.1%</td>
#       <td id="T_a0569_row5_col2" class="data row5 col2" >-0.4%</td>
#       <td id="T_a0569_row5_col3" class="data row5 col3" >+8.0%</td>
#       <td id="T_a0569_row5_col4" class="data row5 col4" >-42.4%</td>
#       <td id="T_a0569_row5_col5" class="data row5 col5" >+0.0%</td>
#     </tr>
#   </tbody>
# </table>
# ### Improvement matrix — Total Spillback (s)
# <style type="text/css">
# #T_f138b_row0_col0, #T_f138b_row1_col1, #T_f138b_row2_col2, #T_f138b_row3_col3, #T_f138b_row4_col4, #T_f138b_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_f138b_row0_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_f138b_row0_col2 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_f138b_row0_col3, #T_f138b_row0_col4, #T_f138b_row1_col0, #T_f138b_row1_col3, #T_f138b_row1_col4, #T_f138b_row1_col5, #T_f138b_row2_col0, #T_f138b_row2_col3, #T_f138b_row2_col4, #T_f138b_row2_col5, #T_f138b_row5_col3, #T_f138b_row5_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f138b_row0_col5 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_f138b_row1_col2 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_f138b_row2_col1 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_f138b_row3_col0 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_f138b_row3_col1, #T_f138b_row3_col2, #T_f138b_row4_col1, #T_f138b_row4_col2, #T_f138b_row4_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f138b_row3_col4 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_f138b_row3_col5, #T_f138b_row4_col0 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_f138b_row4_col3 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_f138b_row5_col0 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_f138b_row5_col1 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_f138b_row5_col2 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f138b_">
#   <caption>Row strategy vs. column strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >RM Only</th>
#       <th class="col_heading level0 col1" >ALINEA</th>
#       <th class="col_heading level0 col2" >PI-ALINEA</th>
#       <th class="col_heading level0 col3" >Fixed-Control</th>
#       <th class="col_heading level0 col4" >No Control</th>
#       <th class="col_heading level0 col5" >RM+LCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f138b_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_f138b_row0_col0" class="data row0 col0" >+0.0%</td>
#       <td id="T_f138b_row0_col1" class="data row0 col1" >+75.2%</td>
#       <td id="T_f138b_row0_col2" class="data row0 col2" >+84.9%</td>
#       <td id="T_f138b_row0_col3" class="data row0 col3" >-5874.7%</td>
#       <td id="T_f138b_row0_col4" class="data row0 col4" >-6642.9%</td>
#       <td id="T_f138b_row0_col5" class="data row0 col5" >+47.3%</td>
#     </tr>
#     <tr>
#       <th id="T_f138b_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_f138b_row1_col0" class="data row1 col0" >-303.9%</td>
#       <td id="T_f138b_row1_col1" class="data row1 col1" >+0.0%</td>
#       <td id="T_f138b_row1_col2" class="data row1 col2" >+39.0%</td>
#       <td id="T_f138b_row1_col3" class="data row1 col3" >-24032.9%</td>
#       <td id="T_f138b_row1_col4" class="data row1 col4" >-27135.7%</td>
#       <td id="T_f138b_row1_col5" class="data row1 col5" >-112.8%</td>
#     </tr>
#     <tr>
#       <th id="T_f138b_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_f138b_row2_col0" class="data row2 col0" >-562.4%</td>
#       <td id="T_f138b_row2_col1" class="data row2 col1" >-64.0%</td>
#       <td id="T_f138b_row2_col2" class="data row2 col2" >+0.0%</td>
#       <td id="T_f138b_row2_col3" class="data row2 col3" >-39474.7%</td>
#       <td id="T_f138b_row2_col4" class="data row2 col4" >-44562.9%</td>
#       <td id="T_f138b_row2_col5" class="data row2 col5" >-248.9%</td>
#     </tr>
#     <tr>
#       <th id="T_f138b_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_f138b_row3_col0" class="data row3 col0" >+98.3%</td>
#       <td id="T_f138b_row3_col1" class="data row3 col1" >+99.6%</td>
#       <td id="T_f138b_row3_col2" class="data row3 col2" >+99.7%</td>
#       <td id="T_f138b_row3_col3" class="data row3 col3" >+0.0%</td>
#       <td id="T_f138b_row3_col4" class="data row3 col4" >-12.9%</td>
#       <td id="T_f138b_row3_col5" class="data row3 col5" >+99.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f138b_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_f138b_row4_col0" class="data row4 col0" >+98.5%</td>
#       <td id="T_f138b_row4_col1" class="data row4 col1" >+99.6%</td>
#       <td id="T_f138b_row4_col2" class="data row4 col2" >+99.8%</td>
#       <td id="T_f138b_row4_col3" class="data row4 col3" >+11.4%</td>
#       <td id="T_f138b_row4_col4" class="data row4 col4" >+0.0%</td>
#       <td id="T_f138b_row4_col5" class="data row4 col5" >+99.2%</td>
#     </tr>
#     <tr>
#       <th id="T_f138b_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_f138b_row5_col0" class="data row5 col0" >-89.8%</td>
#       <td id="T_f138b_row5_col1" class="data row5 col1" >+53.0%</td>
#       <td id="T_f138b_row5_col2" class="data row5 col2" >+71.3%</td>
#       <td id="T_f138b_row5_col3" class="data row5 col3" >-11241.8%</td>
#       <td id="T_f138b_row5_col4" class="data row5 col4" >-12700.0%</td>
#       <td id="T_f138b_row5_col5" class="data row5 col5" >+0.0%</td>
#     </tr>
#   </tbody>
# </table>
# ### Improvement matrix — Average Merge Speed (km/h)
# <style type="text/css">
# #T_029ab_row0_col0, #T_029ab_row0_col2, #T_029ab_row1_col1, #T_029ab_row2_col1, #T_029ab_row2_col2, #T_029ab_row3_col3, #T_029ab_row4_col4, #T_029ab_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_029ab_row0_col1 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_029ab_row0_col3 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_029ab_row0_col4 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_029ab_row0_col5, #T_029ab_row2_col5 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_029ab_row1_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_029ab_row1_col2, #T_029ab_row2_col0 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_029ab_row1_col3, #T_029ab_row4_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_029ab_row1_col4, #T_029ab_row3_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_029ab_row1_col5, #T_029ab_row5_col3 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_029ab_row2_col3 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_029ab_row2_col4 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_029ab_row3_col0, #T_029ab_row3_col2 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_029ab_row3_col4 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_029ab_row3_col5, #T_029ab_row5_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_029ab_row4_col0, #T_029ab_row4_col2 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_029ab_row4_col3 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_029ab_row4_col5 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_029ab_row5_col0, #T_029ab_row5_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_029ab_row5_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# </style>
# <table id="T_029ab_">
#   <caption>Row strategy vs. column strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >RM Only</th>
#       <th class="col_heading level0 col1" >ALINEA</th>
#       <th class="col_heading level0 col2" >PI-ALINEA</th>
#       <th class="col_heading level0 col3" >Fixed-Control</th>
#       <th class="col_heading level0 col4" >No Control</th>
#       <th class="col_heading level0 col5" >RM+LCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_029ab_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_029ab_row0_col0" class="data row0 col0" >+0.0%</td>
#       <td id="T_029ab_row0_col1" class="data row0 col1" >+0.9%</td>
#       <td id="T_029ab_row0_col2" class="data row0 col2" >+0.3%</td>
#       <td id="T_029ab_row0_col3" class="data row0 col3" >-4.7%</td>
#       <td id="T_029ab_row0_col4" class="data row0 col4" >+7.1%</td>
#       <td id="T_029ab_row0_col5" class="data row0 col5" >-1.8%</td>
#     </tr>
#     <tr>
#       <th id="T_029ab_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_029ab_row1_col0" class="data row1 col0" >-0.9%</td>
#       <td id="T_029ab_row1_col1" class="data row1 col1" >+0.0%</td>
#       <td id="T_029ab_row1_col2" class="data row1 col2" >-0.5%</td>
#       <td id="T_029ab_row1_col3" class="data row1 col3" >-5.5%</td>
#       <td id="T_029ab_row1_col4" class="data row1 col4" >+6.2%</td>
#       <td id="T_029ab_row1_col5" class="data row1 col5" >-2.7%</td>
#     </tr>
#     <tr>
#       <th id="T_029ab_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_029ab_row2_col0" class="data row2 col0" >-0.3%</td>
#       <td id="T_029ab_row2_col1" class="data row2 col1" >+0.5%</td>
#       <td id="T_029ab_row2_col2" class="data row2 col2" >+0.0%</td>
#       <td id="T_029ab_row2_col3" class="data row2 col3" >-5.0%</td>
#       <td id="T_029ab_row2_col4" class="data row2 col4" >+6.8%</td>
#       <td id="T_029ab_row2_col5" class="data row2 col5" >-2.2%</td>
#     </tr>
#     <tr>
#       <th id="T_029ab_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_029ab_row3_col0" class="data row3 col0" >+4.9%</td>
#       <td id="T_029ab_row3_col1" class="data row3 col1" >+5.8%</td>
#       <td id="T_029ab_row3_col2" class="data row3 col2" >+5.2%</td>
#       <td id="T_029ab_row3_col3" class="data row3 col3" >+0.0%</td>
#       <td id="T_029ab_row3_col4" class="data row3 col4" >+12.4%</td>
#       <td id="T_029ab_row3_col5" class="data row3 col5" >+2.9%</td>
#     </tr>
#     <tr>
#       <th id="T_029ab_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_029ab_row4_col0" class="data row4 col0" >-6.7%</td>
#       <td id="T_029ab_row4_col1" class="data row4 col1" >-5.8%</td>
#       <td id="T_029ab_row4_col2" class="data row4 col2" >-6.3%</td>
#       <td id="T_029ab_row4_col3" class="data row4 col3" >-11.0%</td>
#       <td id="T_029ab_row4_col4" class="data row4 col4" >+0.0%</td>
#       <td id="T_029ab_row4_col5" class="data row4 col5" >-8.4%</td>
#     </tr>
#     <tr>
#       <th id="T_029ab_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_029ab_row5_col0" class="data row5 col0" >+1.9%</td>
#       <td id="T_029ab_row5_col1" class="data row5 col1" >+2.8%</td>
#       <td id="T_029ab_row5_col2" class="data row5 col2" >+2.2%</td>
#       <td id="T_029ab_row5_col3" class="data row5 col3" >-2.9%</td>
#       <td id="T_029ab_row5_col4" class="data row5 col4" >+9.1%</td>
#       <td id="T_029ab_row5_col5" class="data row5 col5" >+0.0%</td>
#     </tr>
#   </tbody>
# </table>
# ### Improvement matrix — Total CO2 Emissions (mg)
# <style type="text/css">
# #T_c9bb7_row0_col0, #T_c9bb7_row1_col1, #T_c9bb7_row1_col2, #T_c9bb7_row2_col2, #T_c9bb7_row3_col3, #T_c9bb7_row3_col5, #T_c9bb7_row4_col4, #T_c9bb7_row5_col5 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_c9bb7_row0_col1, #T_c9bb7_row0_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_c9bb7_row0_col3, #T_c9bb7_row0_col5 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_c9bb7_row0_col4 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_c9bb7_row1_col0, #T_c9bb7_row2_col0 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_c9bb7_row1_col3, #T_c9bb7_row1_col5 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_c9bb7_row1_col4 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_c9bb7_row2_col1, #T_c9bb7_row5_col3 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_c9bb7_row2_col3, #T_c9bb7_row2_col5 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_c9bb7_row2_col4 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_c9bb7_row3_col0, #T_c9bb7_row5_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_c9bb7_row3_col1, #T_c9bb7_row5_col1, #T_c9bb7_row5_col2 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_c9bb7_row3_col2 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_c9bb7_row3_col4 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_c9bb7_row4_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_c9bb7_row4_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_c9bb7_row4_col2 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_c9bb7_row4_col3, #T_c9bb7_row4_col5 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_c9bb7_row5_col4 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# </style>
# <table id="T_c9bb7_">
#   <caption>Row strategy vs. column strategy</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >RM Only</th>
#       <th class="col_heading level0 col1" >ALINEA</th>
#       <th class="col_heading level0 col2" >PI-ALINEA</th>
#       <th class="col_heading level0 col3" >Fixed-Control</th>
#       <th class="col_heading level0 col4" >No Control</th>
#       <th class="col_heading level0 col5" >RM+LCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9bb7_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_c9bb7_row0_col0" class="data row0 col0" >+0.0%</td>
#       <td id="T_c9bb7_row0_col1" class="data row0 col1" >-9.2%</td>
#       <td id="T_c9bb7_row0_col2" class="data row0 col2" >-8.6%</td>
#       <td id="T_c9bb7_row0_col3" class="data row0 col3" >-14.1%</td>
#       <td id="T_c9bb7_row0_col4" class="data row0 col4" >+1.3%</td>
#       <td id="T_c9bb7_row0_col5" class="data row0 col5" >-13.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c9bb7_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_c9bb7_row1_col0" class="data row1 col0" >+8.5%</td>
#       <td id="T_c9bb7_row1_col1" class="data row1 col1" >+0.0%</td>
#       <td id="T_c9bb7_row1_col2" class="data row1 col2" >+0.6%</td>
#       <td id="T_c9bb7_row1_col3" class="data row1 col3" >-4.4%</td>
#       <td id="T_c9bb7_row1_col4" class="data row1 col4" >+9.6%</td>
#       <td id="T_c9bb7_row1_col5" class="data row1 col5" >-4.2%</td>
#     </tr>
#     <tr>
#       <th id="T_c9bb7_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_c9bb7_row2_col0" class="data row2 col0" >+7.9%</td>
#       <td id="T_c9bb7_row2_col1" class="data row2 col1" >-0.6%</td>
#       <td id="T_c9bb7_row2_col2" class="data row2 col2" >+0.0%</td>
#       <td id="T_c9bb7_row2_col3" class="data row2 col3" >-5.0%</td>
#       <td id="T_c9bb7_row2_col4" class="data row2 col4" >+9.1%</td>
#       <td id="T_c9bb7_row2_col5" class="data row2 col5" >-4.8%</td>
#     </tr>
#     <tr>
#       <th id="T_c9bb7_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_c9bb7_row3_col0" class="data row3 col0" >+12.3%</td>
#       <td id="T_c9bb7_row3_col1" class="data row3 col1" >+4.2%</td>
#       <td id="T_c9bb7_row3_col2" class="data row3 col2" >+4.8%</td>
#       <td id="T_c9bb7_row3_col3" class="data row3 col3" >+0.0%</td>
#       <td id="T_c9bb7_row3_col4" class="data row3 col4" >+13.5%</td>
#       <td id="T_c9bb7_row3_col5" class="data row3 col5" >+0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_c9bb7_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_c9bb7_row4_col0" class="data row4 col0" >-1.3%</td>
#       <td id="T_c9bb7_row4_col1" class="data row4 col1" >-10.7%</td>
#       <td id="T_c9bb7_row4_col2" class="data row4 col2" >-10.0%</td>
#       <td id="T_c9bb7_row4_col3" class="data row4 col3" >-15.6%</td>
#       <td id="T_c9bb7_row4_col4" class="data row4 col4" >+0.0%</td>
#       <td id="T_c9bb7_row4_col5" class="data row4 col5" >-15.3%</td>
#     </tr>
#     <tr>
#       <th id="T_c9bb7_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_c9bb7_row5_col0" class="data row5 col0" >+12.1%</td>
#       <td id="T_c9bb7_row5_col1" class="data row5 col1" >+4.0%</td>
#       <td id="T_c9bb7_row5_col2" class="data row5 col2" >+4.6%</td>
#       <td id="T_c9bb7_row5_col3" class="data row5 col3" >-0.2%</td>
#       <td id="T_c9bb7_row5_col4" class="data row5 col4" >+13.3%</td>
#       <td id="T_c9bb7_row5_col5" class="data row5 col5" >+0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6. Demand-Conditioned KPI Heatmaps
#
# For each KPI, a strategy × demand-cell heatmap. Each column is one of the nine demand conditions (`mainline / on-ramp`), gradient is column-wise so colours rank strategies within that demand.

# %%
demand_cells = [f"{m} / {r}" for m in MAINLINE_LEVELS for r in RAMP_LEVELS]

for metric_key, metric_name in METRICS.items():
    pivot = (
        df.groupby(["strategy", "demand_cell"], observed=True)[metric_key]
        .mean()
        .unstack("demand_cell")
        .reindex(index=present_strategies, columns=demand_cells)
    )

    fig, ax = plt.subplots(figsize=(13, 7))
    cmap = "RdYlGn" if metric_key in HIGHER_IS_BETTER else "RdYlGn_r"
    sns.heatmap(pivot, cmap=cmap, annot=True, fmt=".1f",
                annot_kws={"size": 8}, linewidths=0.4, linecolor="white",
                cbar_kws={"label": metric_name}, ax=ax)
    title = f"{metric_name} — strategy × demand"
    ax.set_title(title, fontsize=14)
    ax.set_xlabel("Demand cell  (Mainline / On-Ramp)")
    ax.set_ylabel("")
    ax.tick_params(axis="x", rotation=35)
    for label in ax.get_yticklabels():
        if label.get_text() == FOCUS_STRATEGY:
            label.set_fontweight("bold")
    save_fig(fig, "demand_heatmaps", title)
    plt.tight_layout()
    plt.show()
    plt.close(fig)
# Out:
# /home/yassermessahli/Documents/GitHub/Ramp-Metering-PFE/.venv/lib/python3.10/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# /home/yassermessahli/Documents/GitHub/Ramp-Metering-PFE/.venv/lib/python3.10/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# /home/yassermessahli/Documents/GitHub/Ramp-Metering-PFE/.venv/lib/python3.10/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# /home/yassermessahli/Documents/GitHub/Ramp-Metering-PFE/.venv/lib/python3.10/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# /home/yassermessahli/Documents/GitHub/Ramp-Metering-PFE/.venv/lib/python3.10/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# /home/yassermessahli/Documents/GitHub/Ramp-Metering-PFE/.venv/lib/python3.10/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# ## 7. Focus Strategy Deep Dive
#
# Everything in this section is computed for **`FOCUS_STRATEGY`**. Change the constant at the top of the notebook and rerun this section to compare any other strategy.

# %%
focus_rank = list(composite.index).index(FOCUS_STRATEGY) + 1
display(Markdown(
    f"### Focus strategy: **{FOCUS_STRATEGY}**\n\n"
    f"Composite rank: **{focus_rank} of {len(composite)}** &nbsp;&nbsp;|&nbsp;&nbsp; "
    f"Composite score: **{composite[FOCUS_STRATEGY]:.3f}**"
))
# Out:
# ### Focus strategy: **RM+LCC**
#
# Composite rank: **2 of 6** &nbsp;&nbsp;|&nbsp;&nbsp; Composite score: **0.778**

# %%
others = [s for s in present_strategies if s != FOCUS_STRATEGY]
rows = []
for other in others:
    row = {"Compared against": other}
    for metric_key, metric_name in METRICS.items():
        row[metric_name] = pct_improvement(
            strategy_means.loc[FOCUS_STRATEGY, metric_key],
            strategy_means.loc[other, metric_key],
            metric_key,
        )
    rows.append(row)
improvement_df = pd.DataFrame(rows).set_index("Compared against")

display(Markdown(f"**% Improvement of {FOCUS_STRATEGY} vs. each other strategy**"))
display(
    improvement_df.style
    .format("{:+.2f}%")
    .background_gradient(cmap="RdYlGn", axis=None, vmin=-50, vmax=50)
)
# Out:
# **% Improvement of RM+LCC vs. each other strategy**
# <style type="text/css">
# #T_3ff5b_row0_col0 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_3ff5b_row0_col1 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_3ff5b_row0_col2 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_3ff5b_row0_col3, #T_3ff5b_row3_col3, #T_3ff5b_row4_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_3ff5b_row0_col4 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_3ff5b_row0_col5 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_3ff5b_row1_col0 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_3ff5b_row1_col1 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_3ff5b_row1_col2 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_3ff5b_row1_col3, #T_3ff5b_row2_col3, #T_3ff5b_row4_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_3ff5b_row1_col4 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_3ff5b_row1_col5 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_3ff5b_row2_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_3ff5b_row2_col1 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_3ff5b_row2_col2, #T_3ff5b_row3_col5 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_3ff5b_row2_col4 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_3ff5b_row2_col5 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_3ff5b_row3_col0 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_3ff5b_row3_col1 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_3ff5b_row3_col2 {
#   background-color: #e0f295;
#   color: #000000;
# }
# #T_3ff5b_row3_col4 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_3ff5b_row4_col0 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_3ff5b_row4_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_3ff5b_row4_col4 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_3ff5b_row4_col5 {
#   background-color: #c9e881;
#   color: #000000;
# }
# </style>
# <table id="T_3ff5b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Time Spent (s)</th>
#       <th class="col_heading level0 col1" >Average Delay (s/veh)</th>
#       <th class="col_heading level0 col2" >Average Queue Length (veh)</th>
#       <th class="col_heading level0 col3" >Total Spillback (s)</th>
#       <th class="col_heading level0 col4" >Average Merge Speed (km/h)</th>
#       <th class="col_heading level0 col5" >Total CO2 Emissions (mg)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Compared against</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ff5b_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_3ff5b_row0_col0" class="data row0 col0" >+2.62%</td>
#       <td id="T_3ff5b_row0_col1" class="data row0 col1" >+10.37%</td>
#       <td id="T_3ff5b_row0_col2" class="data row0 col2" >+0.95%</td>
#       <td id="T_3ff5b_row0_col3" class="data row0 col3" >-89.83%</td>
#       <td id="T_3ff5b_row0_col4" class="data row0 col4" >+1.88%</td>
#       <td id="T_3ff5b_row0_col5" class="data row0 col5" >+12.12%</td>
#     </tr>
#     <tr>
#       <th id="T_3ff5b_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_3ff5b_row1_col0" class="data row1 col0" >+10.76%</td>
#       <td id="T_3ff5b_row1_col1" class="data row1 col1" >+28.36%</td>
#       <td id="T_3ff5b_row1_col2" class="data row1 col2" >-1.09%</td>
#       <td id="T_3ff5b_row1_col3" class="data row1 col3" >+53.00%</td>
#       <td id="T_3ff5b_row1_col4" class="data row1 col4" >+2.76%</td>
#       <td id="T_3ff5b_row1_col5" class="data row1 col5" >+4.00%</td>
#     </tr>
#     <tr>
#       <th id="T_3ff5b_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_3ff5b_row2_col0" class="data row2 col0" >+12.56%</td>
#       <td id="T_3ff5b_row2_col1" class="data row2 col1" >+32.23%</td>
#       <td id="T_3ff5b_row2_col2" class="data row2 col2" >-0.36%</td>
#       <td id="T_3ff5b_row2_col3" class="data row2 col3" >+71.34%</td>
#       <td id="T_3ff5b_row2_col4" class="data row2 col4" >+2.23%</td>
#       <td id="T_3ff5b_row2_col5" class="data row2 col5" >+4.56%</td>
#     </tr>
#     <tr>
#       <th id="T_3ff5b_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_3ff5b_row3_col0" class="data row3 col0" >+3.45%</td>
#       <td id="T_3ff5b_row3_col1" class="data row3 col1" >+16.15%</td>
#       <td id="T_3ff5b_row3_col2" class="data row3 col2" >+7.98%</td>
#       <td id="T_3ff5b_row3_col3" class="data row3 col3" >-11241.77%</td>
#       <td id="T_3ff5b_row3_col4" class="data row3 col4" >-2.86%</td>
#       <td id="T_3ff5b_row3_col5" class="data row3 col5" >-0.23%</td>
#     </tr>
#     <tr>
#       <th id="T_3ff5b_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_3ff5b_row4_col0" class="data row4 col0" >+35.27%</td>
#       <td id="T_3ff5b_row4_col1" class="data row4 col1" >+65.53%</td>
#       <td id="T_3ff5b_row4_col2" class="data row4 col2" >-42.42%</td>
#       <td id="T_3ff5b_row4_col3" class="data row4 col3" >-12700.00%</td>
#       <td id="T_3ff5b_row4_col4" class="data row4 col4" >+9.14%</td>
#       <td id="T_3ff5b_row4_col5" class="data row4 col5" >+13.26%</td>
#     </tr>
#   </tbody>
# </table>

# %%
for metric_key, metric_name in METRICS.items():
    series = strategy_means[metric_key].drop(FOCUS_STRATEGY)
    series = series.sort_values(ascending=metric_sort_ascending(metric_key))
    focus_val = strategy_means.loc[FOCUS_STRATEGY, metric_key]

    fig, ax = plt.subplots(figsize=(10, 6))
    colors = [STRATEGY_COLORS[s] for s in series.index]
    ax.barh(series.index, series.values, color=colors, alpha=0.85)
    ax.axvline(focus_val, color=FOCUS_COLOR, linestyle="--", linewidth=2.2,
               label=f"{FOCUS_STRATEGY} = {focus_val:,.1f}")
    title = f"{metric_name} — competitors vs. focus"
    ax.set_title(title, fontsize=14)
    ax.set_xlabel(metric_name)
    ax.invert_yaxis()
    ax.legend(loc="lower right")
    save_fig(fig, "focus", title)
    plt.tight_layout()
    plt.show()
    plt.close(fig)

# %%
ranks = {}
for metric_key in METRICS:
    ordered = strategy_means[metric_key].sort_values(
        ascending=metric_sort_ascending(metric_key)
    ).index.tolist()
    ranks[METRICS[metric_key]] = ordered.index(FOCUS_STRATEGY) + 1

rank_df = pd.Series(ranks, name="Rank").to_frame()
rank_df["Out of"] = len(present_strategies)

fig, ax = plt.subplots(figsize=(10, 4.5))
y = np.arange(len(rank_df))
ax.hlines(y, 0, len(present_strategies), color="0.85", linewidth=2)
ax.plot(rank_df["Rank"], y, "o", color=FOCUS_COLOR, markersize=12)
for i, (metric_name, row) in enumerate(rank_df.iterrows()):
    ax.text(row["Rank"] + 0.15, i, f"#{row['Rank']}", va="center", fontsize=11, fontweight="bold")
ax.set_yticks(y, labels=rank_df.index)
ax.set_xticks(range(1, len(present_strategies) + 1))
ax.set_xlim(0.5, len(present_strategies) + 0.5)
ax.invert_yaxis()
title = f"Per-KPI rank of {FOCUS_STRATEGY}"
ax.set_title(title, fontsize=14)
ax.set_xlabel("Rank (1 = best)")
ax.grid(axis="x", linestyle="--", color="0.85")
save_fig(fig, "focus", title)
plt.tight_layout()
plt.show()
plt.close(fig)

# %%
focus_df = df[df["strategy"] == FOCUS_STRATEGY]

fig, axes = plt.subplots(2, 3, figsize=(17, 9))
for ax, (metric_key, metric_name) in zip(axes.ravel(), METRICS.items()):
    grouped = (
        focus_df.groupby(["mainline_demand", "on_ramp_demand"], observed=True)[metric_key]
        .mean().unstack("on_ramp_demand").reindex(index=MAINLINE_LEVELS, columns=RAMP_LEVELS)
    )
    for ramp_lvl in RAMP_LEVELS:
        ax.plot(MAINLINE_LEVELS, grouped[ramp_lvl], marker="o",
                linewidth=2, label=ramp_lvl)
    ax.set_title(metric_name, fontsize=12)
    ax.set_xlabel("Mainline demand")
    ax.set_ylabel(metric_name)
    ax.tick_params(axis="x", rotation=15)

axes[0, 0].legend(title="On-ramp demand", loc="best", fontsize=9)
title = f"Demand sensitivity — {FOCUS_STRATEGY}"
fig.suptitle(title, fontsize=15, y=1.02)
save_fig(fig, "focus", title)
plt.tight_layout()
plt.show()
plt.close(fig)

# %%
display(Markdown(f"**Best 5 and worst 5 episodes of {FOCUS_STRATEGY} (ranked by composite per-episode)**"))

episode_norm = pd.DataFrame(
    {k: normalize_metric(focus_df[k], k) for k in METRICS},
    index=focus_df.index,
)
focus_with_score = focus_df.assign(_score=episode_norm.mean(axis=1))
show_cols = ["episode_id", "main_flow_vph", "on_ramp_flow_vph", *METRICS.keys(), "_score"]

best5  = focus_with_score.nlargest(5,  "_score")[show_cols].rename(columns={"_score": "composite"})
worst5 = focus_with_score.nsmallest(5, "_score")[show_cols].rename(columns={"_score": "composite"})

display(Markdown("**Top 5 episodes**"))
display(best5.style.format({c: "{:,.2f}" for c in best5.columns if c != "episode_id"}))
display(Markdown("**Bottom 5 episodes**"))
display(worst5.style.format({c: "{:,.2f}" for c in worst5.columns if c != "episode_id"}))
# Out:
# **Best 5 and worst 5 episodes of RM+LCC (ranked by composite per-episode)**
# **Top 5 episodes**
# <style type="text/css">
# </style>
# <table id="T_9935c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >episode_id</th>
#       <th class="col_heading level0 col1" >main_flow_vph</th>
#       <th class="col_heading level0 col2" >on_ramp_flow_vph</th>
#       <th class="col_heading level0 col3" >total_travel_time</th>
#       <th class="col_heading level0 col4" >avg_time_loss</th>
#       <th class="col_heading level0 col5" >avg_ramp_queue_veh</th>
#       <th class="col_heading level0 col6" >total_spillback_time_sec</th>
#       <th class="col_heading level0 col7" >avg_mainline_speed_mergeArea_km/h</th>
#       <th class="col_heading level0 col8" >total_co2_mg</th>
#       <th class="col_heading level0 col9" >composite</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9935c_level0_row0" class="row_heading level0 row0" >251</th>
#       <td id="T_9935c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9935c_row0_col1" class="data row0 col1" >4,000.00</td>
#       <td id="T_9935c_row0_col2" class="data row0 col2" >1,800.00</td>
#       <td id="T_9935c_row0_col3" class="data row0 col3" >279,325.00</td>
#       <td id="T_9935c_row0_col4" class="data row0 col4" >10.35</td>
#       <td id="T_9935c_row0_col5" class="data row0 col5" >7.94</td>
#       <td id="T_9935c_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_9935c_row0_col7" class="data row0 col7" >14.42</td>
#       <td id="T_9935c_row0_col8" class="data row0 col8" >1,299,215,240.64</td>
#       <td id="T_9935c_row0_col9" class="data row0 col9" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_9935c_level0_row1" class="row_heading level0 row1" >254</th>
#       <td id="T_9935c_row1_col0" class="data row1 col0" >4</td>
#       <td id="T_9935c_row1_col1" class="data row1 col1" >4,000.00</td>
#       <td id="T_9935c_row1_col2" class="data row1 col2" >1,500.00</td>
#       <td id="T_9935c_row1_col3" class="data row1 col3" >280,192.00</td>
#       <td id="T_9935c_row1_col4" class="data row1 col4" >10.76</td>
#       <td id="T_9935c_row1_col5" class="data row1 col5" >8.39</td>
#       <td id="T_9935c_row1_col6" class="data row1 col6" >0.00</td>
#       <td id="T_9935c_row1_col7" class="data row1 col7" >14.61</td>
#       <td id="T_9935c_row1_col8" class="data row1 col8" >1,293,161,432.98</td>
#       <td id="T_9935c_row1_col9" class="data row1 col9" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_9935c_level0_row2" class="row_heading level0 row2" >255</th>
#       <td id="T_9935c_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_9935c_row2_col1" class="data row2 col1" >4,000.00</td>
#       <td id="T_9935c_row2_col2" class="data row2 col2" >1,600.00</td>
#       <td id="T_9935c_row2_col3" class="data row2 col3" >282,511.00</td>
#       <td id="T_9935c_row2_col4" class="data row2 col4" >11.34</td>
#       <td id="T_9935c_row2_col5" class="data row2 col5" >8.53</td>
#       <td id="T_9935c_row2_col6" class="data row2 col6" >0.00</td>
#       <td id="T_9935c_row2_col7" class="data row2 col7" >14.34</td>
#       <td id="T_9935c_row2_col8" class="data row2 col8" >1,293,761,445.87</td>
#       <td id="T_9935c_row2_col9" class="data row2 col9" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_9935c_level0_row3" class="row_heading level0 row3" >271</th>
#       <td id="T_9935c_row3_col0" class="data row3 col0" >21</td>
#       <td id="T_9935c_row3_col1" class="data row3 col1" >4,500.00</td>
#       <td id="T_9935c_row3_col2" class="data row3 col2" >1,900.00</td>
#       <td id="T_9935c_row3_col3" class="data row3 col3" >335,663.00</td>
#       <td id="T_9935c_row3_col4" class="data row3 col4" >14.27</td>
#       <td id="T_9935c_row3_col5" class="data row3 col5" >10.91</td>
#       <td id="T_9935c_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_9935c_row3_col7" class="data row3 col7" >14.37</td>
#       <td id="T_9935c_row3_col8" class="data row3 col8" >1,480,988,922.22</td>
#       <td id="T_9935c_row3_col9" class="data row3 col9" >0.67</td>
#     </tr>
#     <tr>
#       <th id="T_9935c_level0_row4" class="row_heading level0 row4" >285</th>
#       <td id="T_9935c_row4_col0" class="data row4 col0" >35</td>
#       <td id="T_9935c_row4_col1" class="data row4 col1" >4,500.00</td>
#       <td id="T_9935c_row4_col2" class="data row4 col2" >1,900.00</td>
#       <td id="T_9935c_row4_col3" class="data row4 col3" >333,334.00</td>
#       <td id="T_9935c_row4_col4" class="data row4 col4" >15.36</td>
#       <td id="T_9935c_row4_col5" class="data row4 col5" >11.44</td>
#       <td id="T_9935c_row4_col6" class="data row4 col6" >0.00</td>
#       <td id="T_9935c_row4_col7" class="data row4 col7" >14.52</td>
#       <td id="T_9935c_row4_col8" class="data row4 col8" >1,461,282,147.20</td>
#       <td id="T_9935c_row4_col9" class="data row4 col9" >0.67</td>
#     </tr>
#   </tbody>
# </table>
# **Bottom 5 episodes**
# <style type="text/css">
# </style>
# <table id="T_b7998_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >episode_id</th>
#       <th class="col_heading level0 col1" >main_flow_vph</th>
#       <th class="col_heading level0 col2" >on_ramp_flow_vph</th>
#       <th class="col_heading level0 col3" >total_travel_time</th>
#       <th class="col_heading level0 col4" >avg_time_loss</th>
#       <th class="col_heading level0 col5" >avg_ramp_queue_veh</th>
#       <th class="col_heading level0 col6" >total_spillback_time_sec</th>
#       <th class="col_heading level0 col7" >avg_mainline_speed_mergeArea_km/h</th>
#       <th class="col_heading level0 col8" >total_co2_mg</th>
#       <th class="col_heading level0 col9" >composite</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7998_level0_row0" class="row_heading level0 row0" >256</th>
#       <td id="T_b7998_row0_col0" class="data row0 col0" >6</td>
#       <td id="T_b7998_row0_col1" class="data row0 col1" >6,500.00</td>
#       <td id="T_b7998_row0_col2" class="data row0 col2" >2,000.00</td>
#       <td id="T_b7998_row0_col3" class="data row0 col3" >399,098.00</td>
#       <td id="T_b7998_row0_col4" class="data row0 col4" >24.04</td>
#       <td id="T_b7998_row0_col5" class="data row0 col5" >16.55</td>
#       <td id="T_b7998_row0_col6" class="data row0 col6" >520.00</td>
#       <td id="T_b7998_row0_col7" class="data row0 col7" >12.40</td>
#       <td id="T_b7998_row0_col8" class="data row0 col8" >1,636,744,010.76</td>
#       <td id="T_b7998_row0_col9" class="data row0 col9" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_b7998_level0_row1" class="row_heading level0 row1" >278</th>
#       <td id="T_b7998_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_b7998_row1_col1" class="data row1 col1" >6,000.00</td>
#       <td id="T_b7998_row1_col2" class="data row1 col2" >1,800.00</td>
#       <td id="T_b7998_row1_col3" class="data row1 col3" >397,682.00</td>
#       <td id="T_b7998_row1_col4" class="data row1 col4" >23.74</td>
#       <td id="T_b7998_row1_col5" class="data row1 col5" >16.62</td>
#       <td id="T_b7998_row1_col6" class="data row1 col6" >480.00</td>
#       <td id="T_b7998_row1_col7" class="data row1 col7" >12.50</td>
#       <td id="T_b7998_row1_col8" class="data row1 col8" >1,640,612,632.01</td>
#       <td id="T_b7998_row1_col9" class="data row1 col9" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_b7998_level0_row2" class="row_heading level0 row2" >286</th>
#       <td id="T_b7998_row2_col0" class="data row2 col0" >36</td>
#       <td id="T_b7998_row2_col1" class="data row2 col1" >6,000.00</td>
#       <td id="T_b7998_row2_col2" class="data row2 col2" >1,900.00</td>
#       <td id="T_b7998_row2_col3" class="data row2 col3" >392,199.00</td>
#       <td id="T_b7998_row2_col4" class="data row2 col4" >22.94</td>
#       <td id="T_b7998_row2_col5" class="data row2 col5" >16.91</td>
#       <td id="T_b7998_row2_col6" class="data row2 col6" >600.00</td>
#       <td id="T_b7998_row2_col7" class="data row2 col7" >13.51</td>
#       <td id="T_b7998_row2_col8" class="data row2 col8" >1,632,950,043.45</td>
#       <td id="T_b7998_row2_col9" class="data row2 col9" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_b7998_level0_row3" class="row_heading level0 row3" >260</th>
#       <td id="T_b7998_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_b7998_row3_col1" class="data row3 col1" >6,500.00</td>
#       <td id="T_b7998_row3_col2" class="data row3 col2" >1,800.00</td>
#       <td id="T_b7998_row3_col3" class="data row3 col3" >390,424.00</td>
#       <td id="T_b7998_row3_col4" class="data row3 col4" >22.53</td>
#       <td id="T_b7998_row3_col5" class="data row3 col5" >16.11</td>
#       <td id="T_b7998_row3_col6" class="data row3 col6" >520.00</td>
#       <td id="T_b7998_row3_col7" class="data row3 col7" >12.89</td>
#       <td id="T_b7998_row3_col8" class="data row3 col8" >1,631,845,924.87</td>
#       <td id="T_b7998_row3_col9" class="data row3 col9" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_b7998_level0_row4" class="row_heading level0 row4" >294</th>
#       <td id="T_b7998_row4_col0" class="data row4 col0" >44</td>
#       <td id="T_b7998_row4_col1" class="data row4 col1" >6,000.00</td>
#       <td id="T_b7998_row4_col2" class="data row4 col2" >1,900.00</td>
#       <td id="T_b7998_row4_col3" class="data row4 col3" >399,312.00</td>
#       <td id="T_b7998_row4_col4" class="data row4 col4" >24.23</td>
#       <td id="T_b7998_row4_col5" class="data row4 col5" >16.34</td>
#       <td id="T_b7998_row4_col6" class="data row4 col6" >440.00</td>
#       <td id="T_b7998_row4_col7" class="data row4 col7" >13.46</td>
#       <td id="T_b7998_row4_col8" class="data row4 col8" >1,633,689,235.29</td>
#       <td id="T_b7998_row4_col9" class="data row4 col9" >0.12</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 8. Robustness & Trade-offs
#
# - **Coefficient of variation** (std / mean) per strategy per KPI — lower means the strategy behaves more consistently across the 50 episodes.
# - **Trade-off scatter plots** between metric pairs that capture two important tensions: mainline vs ramp fairness, and efficiency vs emissions. Dots are per-strategy means; the focus strategy is highlighted.

# %%
stds  = df.groupby("strategy", sort=False)[list(METRICS)].std().reindex(present_strategies)
means = strategy_means
cov = (stds / means.abs()).rename(columns=METRICS)

display(Markdown("**Coefficient of variation per strategy (lower = more consistent)**"))
display(
    cov.style
    .format("{:.3f}")
    .background_gradient(cmap="RdYlGn_r", axis=0)
)
# Out:
# **Coefficient of variation per strategy (lower = more consistent)**
# <style type="text/css">
# #T_e85d2_row0_col0, #T_e85d2_row5_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_e85d2_row0_col1 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_e85d2_row0_col2 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_e85d2_row0_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_e85d2_row0_col4 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_e85d2_row0_col5 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_e85d2_row1_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_e85d2_row1_col1 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_e85d2_row1_col2, #T_e85d2_row3_col0, #T_e85d2_row3_col1, #T_e85d2_row3_col5, #T_e85d2_row4_col3, #T_e85d2_row5_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e85d2_row1_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_e85d2_row1_col4 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_e85d2_row1_col5 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_e85d2_row2_col0 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_e85d2_row2_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_e85d2_row2_col2 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_e85d2_row2_col3, #T_e85d2_row2_col4, #T_e85d2_row3_col2, #T_e85d2_row5_col0, #T_e85d2_row5_col1, #T_e85d2_row5_col5 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e85d2_row2_col5 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_e85d2_row3_col3 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_e85d2_row3_col4, #T_e85d2_row4_col5 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_e85d2_row4_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_e85d2_row4_col1 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_e85d2_row4_col2 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_e85d2_row4_col4 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_e85d2_row5_col2 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e85d2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Time Spent (s)</th>
#       <th class="col_heading level0 col1" >Average Delay (s/veh)</th>
#       <th class="col_heading level0 col2" >Average Queue Length (veh)</th>
#       <th class="col_heading level0 col3" >Total Spillback (s)</th>
#       <th class="col_heading level0 col4" >Average Merge Speed (km/h)</th>
#       <th class="col_heading level0 col5" >Total CO2 Emissions (mg)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >strategy</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e85d2_level0_row0" class="row_heading level0 row0" >RM Only</th>
#       <td id="T_e85d2_row0_col0" class="data row0 col0" >0.093</td>
#       <td id="T_e85d2_row0_col1" class="data row0 col1" >0.200</td>
#       <td id="T_e85d2_row0_col2" class="data row0 col2" >0.127</td>
#       <td id="T_e85d2_row0_col3" class="data row0 col3" >1.119</td>
#       <td id="T_e85d2_row0_col4" class="data row0 col4" >0.041</td>
#       <td id="T_e85d2_row0_col5" class="data row0 col5" >0.068</td>
#     </tr>
#     <tr>
#       <th id="T_e85d2_level0_row1" class="row_heading level0 row1" >ALINEA</th>
#       <td id="T_e85d2_row1_col0" class="data row1 col0" >0.095</td>
#       <td id="T_e85d2_row1_col1" class="data row1 col1" >0.184</td>
#       <td id="T_e85d2_row1_col2" class="data row1 col2" >0.159</td>
#       <td id="T_e85d2_row1_col3" class="data row1 col3" >0.445</td>
#       <td id="T_e85d2_row1_col4" class="data row1 col4" >0.013</td>
#       <td id="T_e85d2_row1_col5" class="data row1 col5" >0.062</td>
#     </tr>
#     <tr>
#       <th id="T_e85d2_level0_row2" class="row_heading level0 row2" >PI-ALINEA</th>
#       <td id="T_e85d2_row2_col0" class="data row2 col0" >0.106</td>
#       <td id="T_e85d2_row2_col1" class="data row2 col1" >0.208</td>
#       <td id="T_e85d2_row2_col2" class="data row2 col2" >0.152</td>
#       <td id="T_e85d2_row2_col3" class="data row2 col3" >0.319</td>
#       <td id="T_e85d2_row2_col4" class="data row2 col4" >0.012</td>
#       <td id="T_e85d2_row2_col5" class="data row2 col5" >0.066</td>
#     </tr>
#     <tr>
#       <th id="T_e85d2_level0_row3" class="row_heading level0 row3" >Fixed-Control</th>
#       <td id="T_e85d2_row3_col0" class="data row3 col0" >0.140</td>
#       <td id="T_e85d2_row3_col1" class="data row3 col1" >0.338</td>
#       <td id="T_e85d2_row3_col2" class="data row3 col2" >0.009</td>
#       <td id="T_e85d2_row3_col3" class="data row3 col3" >2.050</td>
#       <td id="T_e85d2_row3_col4" class="data row3 col4" >0.034</td>
#       <td id="T_e85d2_row3_col5" class="data row3 col5" >0.083</td>
#     </tr>
#     <tr>
#       <th id="T_e85d2_level0_row4" class="row_heading level0 row4" >No Control</th>
#       <td id="T_e85d2_row4_col0" class="data row4 col0" >0.127</td>
#       <td id="T_e85d2_row4_col1" class="data row4 col1" >0.205</td>
#       <td id="T_e85d2_row4_col2" class="data row4 col2" >0.092</td>
#       <td id="T_e85d2_row4_col3" class="data row4 col3" >2.982</td>
#       <td id="T_e85d2_row4_col4" class="data row4 col4" >0.022</td>
#       <td id="T_e85d2_row4_col5" class="data row4 col5" >0.070</td>
#     </tr>
#     <tr>
#       <th id="T_e85d2_level0_row5" class="row_heading level0 row5" >RM+LCC</th>
#       <td id="T_e85d2_row5_col0" class="data row5 col0" >0.079</td>
#       <td id="T_e85d2_row5_col1" class="data row5 col1" >0.164</td>
#       <td id="T_e85d2_row5_col2" class="data row5 col2" >0.151</td>
#       <td id="T_e85d2_row5_col3" class="data row5 col3" >0.946</td>
#       <td id="T_e85d2_row5_col4" class="data row5 col4" >0.055</td>
#       <td id="T_e85d2_row5_col5" class="data row5 col5" >0.057</td>
#     </tr>
#   </tbody>
# </table>

# %%
def trade_off_plot(x_key: str, y_key: str, title: str, section: str = "tradeoffs"):
    fig, ax = plt.subplots(figsize=(10, 7))
    for strat in present_strategies:
        x = strategy_means.loc[strat, x_key]
        y = strategy_means.loc[strat, y_key]
        is_focus = strat == FOCUS_STRATEGY
        ax.scatter(x, y, s=260 if is_focus else 130,
                   color=STRATEGY_COLORS[strat],
                   edgecolor="black" if is_focus else "0.4",
                   linewidth=2.2 if is_focus else 0.8, zorder=3)
        ax.annotate(strat, (x, y),
                    xytext=(7, 6), textcoords="offset points",
                    fontsize=9, fontweight="bold" if is_focus else "normal")
    ax.set_xlabel(METRICS[x_key])
    ax.set_ylabel(METRICS[y_key])
    ax.set_title(title, fontsize=14)
    ax.grid(True, linestyle="--", color="0.85")
    save_fig(fig, section, title)
    plt.tight_layout()
    plt.show()
    plt.close(fig)

trade_off_plot(
    "avg_time_loss", "avg_ramp_queue_veh",
    "Fairness trade-off — mainline delay vs ramp queue (lower-left is best)",
)

# %%
trade_off_plot(
    "total_travel_time", "total_co2_mg",
    "Efficiency vs emissions — total time spent vs CO2 (lower-left is best)",
)

# %% [markdown]
# ## Wrap-up
#
# - **To deep-dive a different strategy:** set `FOCUS_STRATEGY` at the top to any name from `STRATEGY_CATALOG` and re-run Sections 4–7.
# - **All figures** are saved to `plots/analysis/<section>/<figure>.png`.
# - **Composite score** is a min-max average across the six KPIs (no statistical weighting). Treat the ranking as a visual heuristic, not a formal optimum.
